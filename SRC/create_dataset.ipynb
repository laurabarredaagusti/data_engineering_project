# %%
import sqlite3
import pandas as pd

# %%
connection = sqlite3.connect("../../data/database.sqlite")
crsr = connection.cursor()

# %%
def sql_query(query):

    # Ejecuta la query
    crsr.execute(query)

    # Almacena los datos de la query 
    ans = crsr.fetchall()

    # Obtenemos los nombres de las columnas de la tabla
    names = [description[0] for description in crsr.description]

    return pd.DataFrame(ans,columns=names)

# %%
query_match = '''SELECT * FROM Match'''
query_team = '''SELECT * FROM Team'''

# %%
match_df = sql_query(query_match)
match_df.head()
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0        492473              9987              9993               1  ...
# 1        492474             10000              9994               0  ...
# 2        492475              9984              8635               0  ...
# 3        492476              9991              9998               5  ...
# 4        492477              7947              9985               1  ...
#
#     SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# 0  4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1  3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2  2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3  7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4  1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67
#
# [5 rows x 115 columns]

# %%
team_df = sql_query(query_team)
team_df.head()
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB

# %%
test_query = "SELECT team_long_name FROM Team WHERE team_api_id IS 9987"
result = sql_query(test_query)
print(result.values[0][0])
# Out:
# KRC Genk

# %%
match_df['home_team_name'] = match_df['home_team_api_id'].apply(lambda x: (sql_query(("SELECT team_long_name FROM Team WHERE team_api_id IS " + str(x)))).values[0][0])
match_df['away_team_name'] = match_df['away_team_api_id'].apply(lambda x: (sql_query(("SELECT team_long_name FROM Team WHERE team_api_id IS " + str(x)))).values[0][0])

# %%
match_df.head()
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0        492473              9987              9993               1  ...
# 1        492474             10000              9994               0  ...
# 2        492475              9984              8635               0  ...
# 3        492476              9991              9998               5  ...
# 4        492477              7947              9985               1  ...
#
#     VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA     home_team_name  \
# 0  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20           KRC Genk
# 1  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60   SV Zulte-Waregem
# 2  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75  KSV Cercle Brugge
# 3  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50           KAA Gent
# 4  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67      FCV Dender EH
#
#       away_team_name
# 0       Beerschot AC
# 1   Sporting Lokeren
# 2     RSC Anderlecht
# 3          RAEC Mons
# 4  Standard de Liège
#
# [5 rows x 117 columns]
